# %%
# %matplotlib inline
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import requests
import json
import time
import numpy as np
from yelpapi import YelpAPI
from pprint import pprint
from API import api_key
import scipy.stats as stats
from scipy.stats import linregress
import warnings
warnings.filterwarnings('ignore')

# %%
# creat the code to get the data from yelp 

url = 'https://api.yelp.com/v3/businesses/search'
API = api_key
headers = {'Authorization': 'bearer %s' % API}
offset = 0
business = []


# loop throught the URL to get 500 rows of data 

for i in range(0, 500, 50):
    params = {'location': 'Cleveland, Ohio' , 'offset': offset , 'limit': 50 }
    response = requests.get(url, params=params, headers=headers)
    business.append(response.json())
    offset += 50
    
    if offset % 50 == 0:
        time.sleep(5)

# %%
business[1]['businesses']
# Out:
# [{'id': 'cUwNW5NEua_yMcAx-X2sMg',
#   'alias': 'grumpys-cafe-cleveland',
#   'name': "Grumpy's Cafe",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pxoH6ePSvagPvG9ckRv-Zg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grumpys-cafe-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 328,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.476519, 'longitude': -81.690993},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2621 W 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2621 W 14th St', 'Cleveland, OH 44113']},
#   'phone': '+12162415025',
#   'display_phone': '(216) 241-5025',
#   'distance': 1589.909540735671},
#  {'id': 'bLi48v8Div6Qm2Fyaw0C6Q',
#   'alias': 'hodges-cleveland',
#   'name': "Hodge's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hlK5pWGP08VQayZn8tDlEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hodges-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 351,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.49975, 'longitude': -81.6886899},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '668 Euclid Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44114',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['668 Euclid Ave', 'Cleveland, OH 44114']},
#   'phone': '+12167714000',
#   'display_phone': '(216) 771-4000',
#   'distance': 3191.50990754721},
#  {'id': 's9CG5XGXJQpP03iYFIHeLA',
#   'alias': 'pura-vida-cleveland',
#   'name': 'Pura Vida',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/955K25dNBXFXzj8zBZoEEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pura-vida-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 218,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4993931, 'longitude': -81.6919645},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '170 Euclid Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44114',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['170 Euclid Ave', 'Cleveland, OH 44114']},
#   'phone': '+12169870100',
#   'display_phone': '(216) 987-0100',
#   'distance': 3303.3812098830685},
#  {'id': 'mXaqyzYTqiTc-LrTFAm0Yw',
#   'alias': 'sabor-miami-cafe-and-gallery-cleveland',
#   'name': 'Sabor Miami Cafe & Gallery',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MJp0XRudoD5jAgX6d9YAUA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sabor-miami-cafe-and-gallery-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 64,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 41.42413, 'longitude': -81.6973},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '4848 Broadview Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44109',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['4848 Broadview Rd', 'Cleveland, OH 44109']},
#   'phone': '+14407140202',
#   'display_phone': '(440) 714-0202',
#   'distance': 5862.894413659888},
#  {'id': 'sWRALTHK1SO0-bsWeWWyQw',
#   'alias': 'platform-beer-co-cleveland-3',
#   'name': 'Platform Beer Co',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AYwXnRLUnpFNkh7jAjQwLw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/platform-beer-co-cleveland-3?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 148,
#   'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.47986, 'longitude': -81.71396},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '4125 Lorain Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['4125 Lorain Ave', 'Cleveland, OH 44113']},
#   'phone': '+12162021386',
#   'display_phone': '(216) 202-1386',
#   'distance': 3541.107291583874},
#  {'id': '2L0I4w2_32aVJq-IzhZSig',
#   'alias': 'restore-cold-pressed-cleveland',
#   'name': 'Restore Cold Pressed',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HlLpFs069N-K5xdY45JtZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/restore-cold-pressed-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 107,
#   'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.49977, 'longitude': -81.68483},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1001 Huron Rd E',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44115',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1001 Huron Rd E', 'Cleveland, OH 44115']},
#   'phone': '+12162176689',
#   'display_phone': '(216) 217-6689',
#   'distance': 3101.4590241560445},
#  {'id': 'tjqK6lgvoIbRkQ7QuKRAFQ',
#   'alias': 'the-loop-cleveland',
#   'name': 'The Loop',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VgOuxHrXxpJWtc0dpuuLbA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-loop-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 145,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'vinyl_records', 'title': 'Vinyl Records'},
#    {'alias': 'musicvideo', 'title': 'Music & DVDs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.482357, 'longitude': -81.6895386},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2180 W 11th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2180 W 11th St', 'Cleveland, OH 44113']},
#   'phone': '+12162985096',
#   'display_phone': '(216) 298-5096',
#   'distance': 1742.1759448171017},
#  {'id': 'KHdYW6Wl4wWXW60by60P0A',
#   'alias': 'rebol-cleveland',
#   'name': 'Rebol',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ri3yf8PZLQ67d5ZJQCHOTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rebol-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 156,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.4993503, 'longitude': -81.6939436},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '101 W Superior Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['101 W Superior Ave', 'Cleveland, OH 44113']},
#   'phone': '+12165055898',
#   'display_phone': '(216) 505-5898',
#   'distance': 3401.267899094374},
#  {'id': 'ZRLmQ3oAuspAkk5R6BOfyg',
#   'alias': 'fat-cats-cleveland',
#   'name': 'Fat Cats',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3Tt12T0CkXKCr5TeWq0qSQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fat-cats-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 203,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.48381, 'longitude': -81.68746},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2061 W 10th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2061 W 10th St', 'Cleveland, OH 44113']},
#   'phone': '+12165790200',
#   'display_phone': '(216) 579-0200',
#   'distance': 1706.5796525688768},
#  {'id': '228mfqUuGbnCs1kiupJXZw',
#   'alias': 'map-of-thailand-cleveland',
#   'name': 'Map of Thailand',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qRBXQdZiVV9_k1h9aYWQxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/map-of-thailand-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 182,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.5095, 'longitude': -81.66247},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3710 Payne Ave',
#    'address2': 'Ste 106',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44114',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['3710 Payne Ave', 'Ste 106', 'Cleveland, OH 44114']},
#   'phone': '+12163612220',
#   'display_phone': '(216) 361-2220',
#   'distance': 4081.2795480146906},
#  {'id': 'H3cMcV9KK3g2pi68lDNsng',
#   'alias': 'luxe-kitchen-and-lounge-cleveland',
#   'name': 'Luxe Kitchen & Lounge',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mewQWgyAaOkCle8EKBLU4w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/luxe-kitchen-and-lounge-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 293,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.48357, 'longitude': -81.73091},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '6605 Detroit Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44102',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['6605 Detroit Ave', 'Cleveland, OH 44102']},
#   'phone': '+12169200600',
#   'display_phone': '(216) 920-0600',
#   'distance': 5012.907277396573},
#  {'id': 'hmfAdo6LuVOvBLiu75C8ZA',
#   'alias': 'luca-italian-cuisine-cleveland',
#   'name': 'Luca Italian Cuisine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9NqOVKMfu0oS_4nI5IR9CA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/luca-italian-cuisine-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 169,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.4941643, 'longitude': -81.7049116},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '2100 Superior Viaduct',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2100 Superior Viaduct', 'Cleveland, OH 44113']},
#   'phone': '+12168622761',
#   'display_phone': '(216) 862-2761',
#   'distance': 3559.0915419393054},
#  {'id': 'fja2EnaSxKu1D7uctMhw-w',
#   'alias': 'red-the-steakhouse-cleveland-3',
#   'name': 'Red The Steakhouse',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ofm0FCfl-9Xu7h9x-x9dhA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/red-the-steakhouse-cleveland-3?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 202,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.498484, 'longitude': -81.6894706},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '417 Prospect Ave E',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44115',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['417 Prospect Ave E', 'Cleveland, OH 44115']},
#   'phone': '+12166640941',
#   'display_phone': '(216) 664-0941',
#   'distance': 3144.3393611028564},
#  {'id': 'M4RwZL5bTBTwwbVcoaDbtw',
#   'alias': 'rowley-inn-cleveland',
#   'name': 'Rowley Inn',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mPaR7eL5etcmJ3Hf4ObEwA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rowley-inn-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 102,
#   'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.4689993, 'longitude': -81.6878849},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1104 Rowley Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44109',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1104 Rowley Ave', 'Cleveland, OH 44109']},
#   'phone': '+12167955345',
#   'display_phone': '(216) 795-5345',
#   'distance': 1383.4300810329428},
#  {'id': 'MX3TL4-ij22rLFBD1XjKGw',
#   'alias': 'fahrenheit-cleveland-2',
#   'name': 'Fahrenheit',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sipt1J5D-TqytvebFLKD_A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fahrenheit-cleveland-2?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 272,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.47974, 'longitude': -81.68458},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '2417 Professor Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2417 Professor Ave', 'Cleveland, OH 44113']},
#   'phone': '+12167818858',
#   'display_phone': '(216) 781-8858',
#   'distance': 1231.2158459926795},
#  {'id': 'o4HbgQnUkYnTLsbb6K5hjg',
#   'alias': 'society-lounge-cleveland',
#   'name': 'Society Lounge',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/shLVlUVNCIWbnIz3K3_u1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/society-lounge-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 212,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4990300478702,
#    'longitude': -81.6900841240656},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2063 E 4th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44115',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2063 E 4th St', 'Cleveland, OH 44115']},
#   'phone': '+12167819050',
#   'display_phone': '(216) 781-9050',
#   'distance': 3207.679455519581},
#  {'id': 'Ur4eYOFq4qVLHkZJNmcqfQ',
#   'alias': 'prosperity-social-club-cleveland',
#   'name': 'Prosperity Social Club',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EI3Rq-EFhU1ROBEWFC5AbA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prosperity-social-club-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 205,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4770698547363,
#    'longitude': -81.6897888183594},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1109 Starkweather Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1109 Starkweather Ave', 'Cleveland, OH 44113']},
#   'phone': '+12169371938',
#   'display_phone': '(216) 937-1938',
#   'distance': 1507.415673311453},
#  {'id': 'xzQzJTu47vNCYlpB8jdMaw',
#   'alias': 'georges-kitchen-cleveland',
#   'name': "George's  Kitchen",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J8k-CofyoRICyR-rtzkmvw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/georges-kitchen-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 195,
#   'categories': [{'alias': 'diners', 'title': 'Diners'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.464958, 'longitude': -81.783099},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '13101 Triskett Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44111',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['13101 Triskett Rd', 'Cleveland, OH 44111']},
#   'phone': '+12166710430',
#   'display_phone': '(216) 671-0430',
#   'distance': 9274.293266228562},
#  {'id': 'wTTNXThF1RQ3Lu5FnujmOA',
#   'alias': 'banter-beer-and-wine-cleveland',
#   'name': 'Banter Beer & Wine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iU1sFarQLcRpDo3MPKP6uw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/banter-beer-and-wine-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 124,
#   'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.4828338485793,
#    'longitude': -81.7353930723446},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7320 Detroit Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44102',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['7320 Detroit Ave', 'Cleveland, OH 44102']},
#   'phone': '+12168010305',
#   'display_phone': '(216) 801-0305',
#   'distance': 5354.244311957917},
#  {'id': '50vVs0Mtrt1AYt74cEKLDA',
#   'alias': 'brewnuts-cleveland',
#   'name': 'Brewnuts',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7_ocd24HcotcLRZACBY5Ow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brewnuts-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 157,
#   'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4838906079386,
#    'longitude': -81.7304308918762},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '6501 Detroit Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44102',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['6501 Detroit Ave', 'Cleveland, OH 44102']},
#   'phone': '+12166009579',
#   'display_phone': '(216) 600-9579',
#   'distance': 4975.636597507349},
#  {'id': 'SoCjdgcYyj05tSPWz6MUXg',
#   'alias': 'pupuseria-la-bendicion-cleveland',
#   'name': 'Pupuseria La Bendicion',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ED5unEKrA683f7vS0j8FUQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pupuseria-la-bendicion-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 120,
#   'categories': [{'alias': 'salvadoran', 'title': 'Salvadoran'},
#    {'alias': 'colombian', 'title': 'Colombian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.4521747, 'longitude': -81.7590704},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3685 W 105th St',
#    'address2': None,
#    'address3': None,
#    'city': 'Cleveland',
#    'zip_code': '44111',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['3685 W 105th St', 'Cleveland, OH 44111']},
#   'phone': '+12166880338',
#   'display_phone': '(216) 688-0338',
#   'distance': 7591.461180684268},
#  {'id': 'yh0mvFCjZuMKy562h2_d_A',
#   'alias': 'minh-anh-vietnamese-restaurant-cleveland',
#   'name': 'Minh-Anh Vietnamese Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sCYslSu9WtLufw3ir-VURw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/minh-anh-vietnamese-restaurant-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 175,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4856645647016,
#    'longitude': -81.7243166948682},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '5428 Detroit Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44102',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['5428 Detroit Ave', 'Cleveland, OH 44102']},
#   'phone': '+12169619671',
#   'display_phone': '(216) 961-9671',
#   'distance': 4571.789206081287},
#  {'id': '63ieHAevJ5szVnClT8FzGQ',
#   'alias': 'phoenix-coffee-bar-cleveland',
#   'name': 'Phoenix Coffee Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mEW_AveEp5g_fhlVHXd_dg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/phoenix-coffee-bar-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 99,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.4841834138661,
#    'longitude': -81.7088529064545},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3000 Bridge Ave',
#    'address2': 'Ste A',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['3000 Bridge Ave', 'Ste A', 'Cleveland, OH 44113']},
#   'phone': '+12164007901',
#   'display_phone': '(216) 400-7901',
#   'distance': 3267.0295111335486},
#  {'id': 'SGZAsdQAp0SjtMDjXWBPYw',
#   'alias': 'banana-blossom-thai-cuisine-cleveland',
#   'name': 'Banana Blossom Thai Cuisine',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Il1IMlmM3MiY85899eNaqw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/banana-blossom-thai-cuisine-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 152,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.48889, 'longitude': -81.70902},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2800 Clinton Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2800 Clinton Ave', 'Cleveland, OH 44113']},
#   'phone': '+12166965529',
#   'display_phone': '(216) 696-5529',
#   'distance': 3508.007261874832},
#  {'id': 'H1j34TgbrVZkxeww9xlJTw',
#   'alias': 'steves-gyros-cleveland',
#   'name': "Steve's Gyros",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6-bi--u6a99Aiwt_nwPSKQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/steves-gyros-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 152,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4847984313965,
#    'longitude': -81.7029876708984},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1979 W 25th St',
#    'address2': '',
#    'address3': 'Stand E-13 In the West Side Market',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1979 W 25th St',
#     'Stand E-13 In the West Side Market',
#     'Cleveland, OH 44113']},
#   'phone': '+12165669825',
#   'display_phone': '(216) 566-9825',
#   'distance': 2822.282973471724},
#  {'id': 'bgNmUYcraelf27TviWEMGA',
#   'alias': 'inn-on-coventry-cleveland',
#   'name': 'Inn On Coventry',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2WebENcuaS9LgKlUtOUr4A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/inn-on-coventry-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 273,
#   'categories': [{'alias': 'diners', 'title': 'Diners'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.50842, 'longitude': -81.58051},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2785 Euclid Heights Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44106',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2785 Euclid Heights Blvd', 'Cleveland, OH 44106']},
#   'phone': '+12163711811',
#   'display_phone': '(216) 371-1811',
#   'distance': 8594.115675453952},
#  {'id': 'JBt7b3Z9of23xuz3_uIq3Q',
#   'alias': 'beet-jar-juicebar-and-takeaway-cleveland',
#   'name': 'Beet Jar Juicebar & Takeaway',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/veJABoxEPxz3obrcDAQkNg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/beet-jar-juicebar-and-takeaway-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 77,
#   'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.4894702, 'longitude': -81.7110793},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1432 W 29th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1432 W 29th St', 'Cleveland, OH 44113']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3686.134112758498},
#  {'id': 'WG3zvUktE1l3llwq3PPVVg',
#   'alias': 'nates-deli-and-restaurant-cleveland',
#   'name': "Nate's Deli & Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SW3qsdBR-UbywfVVlVbBAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nates-deli-and-restaurant-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 116,
#   'categories': [{'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.48522, 'longitude': -81.70397},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1923 W 25th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1923 W 25th St', 'Cleveland, OH 44113']},
#   'phone': '+12166967529',
#   'display_phone': '(216) 696-7529',
#   'distance': 2943.126758376782},
#  {'id': 'JkQSLe_rBftbTJdZuQFlSw',
#   'alias': 'chinato-cleveland',
#   'name': 'Chinato',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_uhHhyzK_p39JWl6eIrZWw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chinato-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 280,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.498764, 'longitude': -81.6898654},
#   'transactions': ['pickup'],
#   'price': '$$$',
#   'location': {'address1': '2079 E 4th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44115',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2079 E 4th St', 'Cleveland, OH 44115']},
#   'phone': '+12162989080',
#   'display_phone': '(216) 298-9080',
#   'distance': 3147.8038185563014},
#  {'id': 'LvnOhs9Udhyp5adF7Cq98g',
#   'alias': 'sushi-86-cleveland-2',
#   'name': 'Sushi 86',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LHWvUTqjOh5cdWEmSfg1Vw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-86-cleveland-2?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 191,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.498450233886, 'longitude': -81.6889455073791},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '509 Prospect Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44115',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['509 Prospect Ave', 'Cleveland, OH 44115']},
#   'phone': '+12166218686',
#   'display_phone': '(216) 621-8686',
#   'distance': 3107.275376550327},
#  {'id': '02E9r4BQzVrA76Bf7G-KMw',
#   'alias': 'edisons-pizza-kitchen-cleveland',
#   'name': "Edison's Pizza Kitchen",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ELtlT31aMpZBKi_HH1JIoQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/edisons-pizza-kitchen-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 173,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4801232907739,
#    'longitude': -81.6850423869337},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2365 Professor Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2365 Professor Ave', 'Cleveland, OH 44113']},
#   'phone': '+12162984484',
#   'display_phone': '(216) 298-4484',
#   'distance': 1292.892785120144},
#  {'id': '97V91GSG-OQvrvOc9GXoGA',
#   'alias': 'phusion-cafe-cleveland',
#   'name': 'Phusion Cafe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7O6SD4-K2z5yiTsidMvOAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/phusion-cafe-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 141,
#   'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.51056, 'longitude': -81.6698},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3030 Superior Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44114',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['3030 Superior Ave', 'Cleveland, OH 44114']},
#   'phone': '+12168613399',
#   'display_phone': '(216) 861-3399',
#   'distance': 4127.849574573042},
#  {'id': 'HNs2Nf-trqFTDtho4vhfmA',
#   'alias': 'the-south-side-cleveland-2',
#   'name': 'The South Side',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UwuX5EahkTYp45e3cKWwjg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-south-side-cleveland-2?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 311,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.48202, 'longitude': -81.68897},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2207 W 11th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2207 W 11th St', 'Cleveland, OH 44113']},
#   'phone': '+12169372288',
#   'display_phone': '(216) 937-2288',
#   'distance': 1685.4541450346035},
#  {'id': 'tZpxk604kWWHsJKyirraZg',
#   'alias': 'lj-shanghai-cleveland',
#   'name': 'LJ Shanghai',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FiFHWZggidYPYwfml3uxiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lj-shanghai-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 139,
#   'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.5110026135085, 'longitude': -81.668807345474},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3142 Superior Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Cleveland',
#    'zip_code': '44114',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['3142 Superior Ave', 'Cleveland, OH 44114']},
#   'phone': '+12164006936',
#   'display_phone': '(216) 400-6936',
#   'distance': 4189.631215269247},
#  {'id': '9IJ-TE4HEcAJQkUtc1A_Vw',
#   'alias': 'parallax-restaurant-and-lounge-cleveland',
#   'name': 'Parallax Restaurant and Lounge',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L3LaDS7NzeDPh5geiaNsTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/parallax-restaurant-and-lounge-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 202,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4824, 'longitude': -81.68902},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '2179 W 11th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2179 W 11th St', 'Cleveland, OH 44113']},
#   'phone': '+12165839999',
#   'display_phone': '(216) 583-9999',
#   'distance': 1712.7538567861145},
#  {'id': 'Y-oPVMkxgEsve1sG2iDLXA',
#   'alias': 'citizen-pie-cleveland',
#   'name': 'Citizen Pie',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PeKdTFv5oNWPtrOHWMCktA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/citizen-pie-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 131,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.5711347190889,
#    'longitude': -81.5705552082177},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '15710 Waterloo Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44110',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['15710 Waterloo Rd', 'Cleveland, OH 44110']},
#   'phone': '+12164172742',
#   'display_phone': '(216) 417-2742',
#   'distance': 13780.289752360974},
#  {'id': 'Ih0f0UyhFufm3C7kR72DSQ',
#   'alias': 'dante-tremont',
#   'name': 'Dante',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gIbIjfM6eTy391AELGulnw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dante-tremont?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 291,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.48154, 'longitude': -81.68617},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '2247 Professor Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Tremont',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2247 Professor Ave', 'Tremont, OH 44113']},
#   'phone': '+12162741200',
#   'display_phone': '(216) 274-1200',
#   'distance': 1480.0659569734885},
#  {'id': 'was-ZYQR2VKyyWrlkQnQWQ',
#   'alias': 'corner-11-bowl-and-wrap-cleveland-3',
#   'name': 'Corner 11 Bowl & Wrap',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0FlgBcx8psiBOY2Sf1IWzQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/corner-11-bowl-and-wrap-cleveland-3?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 56,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'poke', 'title': 'Poke'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.47948, 'longitude': -81.68903},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2391 W 11th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2391 W 11th St', 'Cleveland, OH 44113']},
#   'phone': '+12167131757',
#   'display_phone': '(216) 713-1757',
#   'distance': 1542.371976934681},
#  {'id': 'jA3xcba82t8x06H8NzG4VQ',
#   'alias': 'the-black-pig-cleveland-2',
#   'name': 'The Black Pig',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CXCk6A6xx403ekxTOdtLMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-black-pig-cleveland-2?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 141,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4847984313965, 'longitude': -81.706657409668},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2801 Bridge Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2801 Bridge Ave', 'Cleveland, OH 44113']},
#   'phone': '+12168627551',
#   'display_phone': '(216) 862-7551',
#   'distance': 3125.099895407353},
#  {'id': 'KnaIbUk-eQm_tEsENO1oFw',
#   'alias': 'ohio-kabob-grill-cleveland',
#   'name': 'Ohio Kabob Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S3cyugaBkqJnMAKM5OmVaw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ohio-kabob-grill-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 76,
#   'categories': [{'alias': 'afghani', 'title': 'Afghan'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.46111, 'longitude': -81.76876},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3359 W 117 St',
#    'address2': None,
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44111',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['3359 W 117 St', 'Cleveland, OH 44111']},
#   'phone': '+12166754775',
#   'display_phone': '(216) 675-4775',
#   'distance': 8128.2509520017775},
#  {'id': 'bj983gybZceLrdUBeCahkQ',
#   'alias': 'phoenix-coffee-cleveland-10',
#   'name': 'Phoenix Coffee',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s4kbJlK9jOxwtD0N9WQpKA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/phoenix-coffee-cleveland-10?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 80,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.50141, 'longitude': -81.68831},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1700 E 9th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44114',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1700 E 9th St', 'Cleveland, OH 44114']},
#   'phone': '+12167715282',
#   'display_phone': '(216) 771-5282',
#   'distance': 3381.972856898794},
#  {'id': 'ZxYPXtZQ-6DFyl4VQkTELQ',
#   'alias': 'washington-place-bistro-cleveland',
#   'name': 'Washington Place Bistro',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EDFvgUIF0oV1IVm-fss_fA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/washington-place-bistro-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 160,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.504454, 'longitude': -81.600514},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2203 Cornell Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44106',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2203 Cornell Rd', 'Cleveland, OH 44106']},
#   'phone': '+12167916500',
#   'display_phone': '(216) 791-6500',
#   'distance': 6908.330335304932},
#  {'id': 'EP1do6l8hLyIGEru0gN3EQ',
#   'alias': 'johnny-mango-world-cafe-and-bar-cleveland',
#   'name': 'Johnny Mango World Cafe & Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yn7xH72Ft4azgm3jB-G3AA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/johnny-mango-world-cafe-and-bar-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 246,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.48374, 'longitude': -81.70994},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3120 Bridge Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['3120 Bridge Ave', 'Cleveland, OH 44113']},
#   'phone': '+12165751919',
#   'display_phone': '(216) 575-1919',
#   'distance': 3331.8069896421925},
#  {'id': '9bxrdL-pQg6SVMFmDcg1ow',
#   'alias': 'rising-star-coffee-roasters-cleveland-3',
#   'name': 'Rising Star Coffee Roasters',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XmC6tpUAJO8L5WBu2FPo8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rising-star-coffee-roasters-cleveland-3?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 99,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#    {'alias': 'wholesale_stores', 'title': 'Wholesale Stores'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.50381, 'longitude': -81.6004},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2187 Murray Hill Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44106',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2187 Murray Hill Rd', 'Cleveland, OH 44106']},
#   'phone': '+12168604897',
#   'display_phone': '(216) 860-4897',
#   'distance': 6886.089717707562},
#  {'id': '2tfMXjOotr1r168mVttUmQ',
#   'alias': 'local-west-cleveland',
#   'name': 'Local West',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4hlhcuJ36r3Svix2IFHRBg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/local-west-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 114,
#   'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.4828415, 'longitude': -81.7355576},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7400 Detroit Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44102',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['7400 Detroit Ave', 'Cleveland, OH 44102']},
#   'phone': '+12164177001',
#   'display_phone': '(216) 417-7001',
#   'distance': 5368.098297004771},
#  {'id': 'iWLNyADtZsORV58bttRrBQ',
#   'alias': 'pizza-216-cleveland',
#   'name': 'Pizza 216',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x_z2Oh3prMBTsRMZnmDJiQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizza-216-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 163,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.4998897413292,
#    'longitude': -81.6902889773233},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '401 Euclid Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44114',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['401 Euclid Ave', 'Cleveland, OH 44114']},
#   'phone': '+12167417992',
#   'display_phone': '(216) 741-7992',
#   'distance': 3300.523759511173},
#  {'id': 'LJwS9epPXXvzel7bZ616Gg',
#   'alias': 'marble-room-steaks-and-raw-bar-cleveland',
#   'name': 'Marble Room Steaks and Raw Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pjfyq7Hbk72kLd6P0IaamQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marble-room-steaks-and-raw-bar-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 154,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.5003939674634,
#    'longitude': -81.6888146409915},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '623 Euclid Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44114',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['623 Euclid Ave', 'Cleveland, OH 44114']},
#   'phone': '+12165237000',
#   'display_phone': '(216) 523-7000',
#   'distance': 3297.724581520952},
#  {'id': 'IYpaW7h8aPYKIK84_ZKMIg',
#   'alias': 'puente-viejo-cleveland',
#   'name': 'Puente Viejo',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ajxjsVyKGxc-nz3L6HVE8Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/puente-viejo-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 130,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.5002431224198,
#    'longitude': -81.6830575838685},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1220 Huron Rd E',
#    'address2': '',
#    'address3': None,
#    'city': 'Cleveland',
#    'zip_code': '44115',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1220 Huron Rd E', 'Cleveland, OH 44115']},
#   'phone': '+12167132689',
#   'display_phone': '(216) 713-2689',
#   'distance': 3112.928953912264},
#  {'id': 'rnvKg9DtsAIHWU4eywsqmA',
#   'alias': 'boney-fingers-bbq-cleveland',
#   'name': 'Boney Fingers BBQ',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SVYlKLKid2Dn3u7SRCmrJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boney-fingers-bbq-cleveland?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 55,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.49994, 'longitude': -81.69035},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '401 Euclid Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44114',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['401 Euclid Ave', 'Cleveland, OH 44114']},
#   'phone': '+12167368760',
#   'display_phone': '(216) 736-8760',
#   'distance': 3307.093547454305},
#  {'id': 'Gh2kkOnzieYqe5cVLtl7MA',
#   'alias': 'tabletop-board-game-cafe-cleveland-2',
#   'name': 'Tabletop Board Game Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NxKJVNQxf1MFFDy-d7TO2Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tabletop-board-game-cafe-cleveland-2?adjust_creative=TshdU4XV3-ETjsHU3-ICtw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TshdU4XV3-ETjsHU3-ICtw',
#   'review_count': 82,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tabletopgames', 'title': 'Tabletop Games'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.4864311, 'longitude': -81.7053909},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1810 W 25th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cleveland',
#    'zip_code': '44113',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1810 W 25th St', 'Cleveland, OH 44113']},
#   'phone': '+12165123053',
#   'display_phone': '(216) 512-3053',
#   'distance': 3109.350962662312}]

# %%
# creat a loop that will open all the 10 json files togeather

full_data = []
for data in business:
    full_data = full_data + data["businesses"]
    


len(full_data)
# Out:
# 500

# %%
# convert 10 json files to a DF

df = pd.DataFrame.from_dict(full_data)
df
# Out:
#                                             alias  \
# 0                                  lola-cleveland
# 1                            townhall-cleveland-2
# 2                            l-albatros-cleveland
# 3                    slymans-restaurant-cleveland
# 4            sokolowskis-university-inn-cleveland
# 5         great-lakes-brewing-company-cleveland-4
# 6                             momocho-cleveland-2
# 7                         luckys-cafe-cleveland-3
# 8                             happy-dog-cleveland
# 9                          superior-pho-cleveland
# 10                 mia-bella-restaurant-cleveland
# 11                 soho-chicken-whiskey-cleveland
# 12                           mabels-bbq-cleveland
# 13           porco-lounge-and-tiki-room-cleveland
# 14        rising-star-coffee-roasters-cleveland-2
# 15                      masons-creamery-cleveland
# 16                    jack-frost-donuts-cleveland
# 17              the-greenhouse-tavern-cleveland-2
# 18                     tremont-taphouse-cleveland
# 19                crop-bistro-and-bar-cleveland-3
# 20                            boaz-cafe-cleveland
# 21                               barrio-cleveland
# 22                       bakersfield-cleveland-15
# 23                    velvet-tango-room-cleveland
# 24               butcher-and-the-brewer-cleveland
# 25       the-bourbon-street-barrel-room-cleveland
# 26                           flying-fig-cleveland
# 27                                ginko-cleveland
# 28                    blue-point-grille-cleveland
# 29                       pour-cleveland-cleveland
# ..                                            ...
# 470                  touch-supper-truck-cleveland
# 471                    duck-island-club-cleveland
# 472  cleveland-tiffin-punjabi-dhaba-north-randall
# 473                     joe-maxx-coffee-cleveland
# 474   rubins-family-restaurant-and-deli-cleveland
# 475         east-end-restaurant-and-bar-cleveland
# 476                     guys-pizza-co-cleveland-3
# 477               wrap-it-up-food-truck-cleveland
# 478                      casamels-pizza-cleveland
# 479                pho-and-rice-cleveland-heights
# 480     cha-spirits-and-pizza-kitchen-cleveland-2
# 481                           la-fiesta-cleveland
# 482             mazzone-and-sons-bakery-cleveland
# 483                       public-square-cleveland
# 484                          cozumel-independence
# 485   zoma-ethiopian-restaurant-cleveland-heights
# 486                azure-rooftop-lounge-cleveland
# 487     gentiles-bakery-catering-and-deli-parma-2
# 488                               shays-cleveland
# 489            cleveland-history-center-cleveland
# 490                            dive-bar-cleveland
# 491                       roses-braai-cleveland-2
# 492                    tick-tock-tavern-cleveland
# 493     cedarland-mediterranean-cuisine-cleveland
# 494                   slymans-tavern-independence
# 495                  angies-soul-cafe-cleveland-2
# 496                      souper-market-lakewood-2
# 497                        cafe-ah-roma-cleveland
# 498                       the-hot-dog-diner-parma
# 499                        dragon-light-cleveland
#
#                                             categories  \
# 0    [{'alias': 'wine_bars', 'title': 'Wine Bars'},...
# 1    [{'alias': 'newamerican', 'title': 'American (...
# 2             [{'alias': 'french', 'title': 'French'}]
# 3    [{'alias': 'tradamerican', 'title': 'American ...
# 4    [{'alias': 'polish', 'title': 'Polish'}, {'ali...
# 5    [{'alias': 'breweries', 'title': 'Breweries'},...
# 6           [{'alias': 'mexican', 'title': 'Mexican'}]
# 7    [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 8    [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 9    [{'alias': 'vietnamese', 'title': 'Vietnamese'...
# 10   [{'alias': 'mediterranean', 'title': 'Mediterr...
# 11   [{'alias': 'southern', 'title': 'Southern'}, {...
# 12   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 13       [{'alias': 'tikibars', 'title': 'Tiki Bars'}]
# 14   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 15   [{'alias': 'icecream', 'title': 'Ice Cream & F...
# 16   [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...
# 17   [{'alias': 'newamerican', 'title': 'American (...
# 18   [{'alias': 'gastropubs', 'title': 'Gastropubs'...
# 19   [{'alias': 'tradamerican', 'title': 'American ...
# 20   [{'alias': 'mediterranean', 'title': 'Mediterr...
# 21   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 22   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 23   [{'alias': 'lounges', 'title': 'Lounges'}, {'a...
# 24   [{'alias': 'newamerican', 'title': 'American (...
# 25   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 26   [{'alias': 'newamerican', 'title': 'American (...
# 27   [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 28          [{'alias': 'seafood', 'title': 'Seafood'}]
# 29      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# ..                                                 ...
# 470  [{'alias': 'streetvendors', 'title': 'Street V...
# 471      [{'alias': 'divebars', 'title': 'Dive Bars'}]
# 472           [{'alias': 'indpak', 'title': 'Indian'}]
# 473  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 474  [{'alias': 'tradamerican', 'title': 'American ...
# 475  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 476  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 477  [{'alias': 'foodtrucks', 'title': 'Food Trucks...
# 478  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 479  [{'alias': 'vietnamese', 'title': 'Vietnamese'...
# 480  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 481  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 482  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 483             [{'alias': 'parks', 'title': 'Parks'}]
# 484         [{'alias': 'mexican', 'title': 'Mexican'}]
# 485  [{'alias': 'ethiopian', 'title': 'Ethiopian'},...
# 486         [{'alias': 'lounges', 'title': 'Lounges'}]
# 487  [{'alias': 'delis', 'title': 'Delis'}, {'alias...
# 488  [{'alias': 'newamerican', 'title': 'American (...
# 489  [{'alias': 'landmarks', 'title': 'Landmarks & ...
# 490      [{'alias': 'divebars', 'title': 'Dive Bars'}]
# 491            [{'alias': 'bbq', 'title': 'Barbeque'}]
# 492  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 493  [{'alias': 'mediterranean', 'title': 'Mediterr...
# 494  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 495      [{'alias': 'soulfood', 'title': 'Soul Food'}]
# 496  [{'alias': 'soup', 'title': 'Soup'}, {'alias':...
# 497     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 498  [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'a...
# 499         [{'alias': 'chinese', 'title': 'Chinese'}]
#
#                                            coordinates   display_phone  \
# 0       {'latitude': 41.49883, 'longitude': -81.69035}  (216) 621-5652
# 1     {'latitude': 41.485492, 'longitude': -81.703914}  (216) 344-9400
# 2    {'latitude': 41.5117439550152, 'longitude': -8...  (216) 791-7880
# 3       {'latitude': 41.51286, 'longitude': -81.67125}  (216) 621-3760
# 4       {'latitude': 41.48475, 'longitude': -81.69005}  (216) 771-9236
# 5    {'latitude': 41.4844102, 'longitude': -81.7043...  (216) 771-4404
# 6    {'latitude': 41.4840151, 'longitude': -81.7098...  (216) 694-2122
# 7       {'latitude': 41.47736, 'longitude': -81.68308}  (216) 622-7773
# 8    {'latitude': 41.4848327636719, 'longitude': -8...  (216) 651-9474
# 9        {'latitude': 41.51056, 'longitude': -81.6698}  (216) 781-7462
# 10   {'latitude': 41.5085151, 'longitude': -81.5976...  (216) 795-2355
# 11   {'latitude': 41.4857177734375, 'longitude': -8...  (216) 298-9090
# 12   {'latitude': 41.4989512054125, 'longitude': -8...  (216) 417-8823
# 13    {'latitude': 41.477766, 'longitude': -81.698763}  (216) 802-9222
# 499  https://s3-media4.fl.yelpcdn.com/bphoto/_F06h7...      False
#
#                                               location  \
# 0    {'address1': '2058 E 4th St', 'address2': '', ...
# 1    {'address1': '1909 W 25th St', 'address2': '',...
# 2    {'address1': '11401 Bellflower Rd', 'address2'...
# 3    {'address1': '3106 Saint Clair Ave NE', 'addre...
# 4    {'address1': '1201 University Rd', 'address2':...
# 5    {'address1': '2516 Market Ave', 'address2': ''...
# 6    {'address1': '1835 Fulton Rd', 'address2': Non...
# 7    {'address1': '777 Starkweather Ave', 'address2...
# 8    {'address1': '5801 Detroit Ave', 'address2': '...
# 9    {'address1': '3030 Superior Ave E', 'address2'...
# 10   {'address1': '12200 Mayfield Rd', 'address2': ...
# 11   {'address1': '1889 W 25th St', 'address2': '',...
# 12   {'address1': '2050 E 4th St', 'address2': '', ...
# 13   {'address1': '2527 W 25th St', 'address2': '',...
# 14   {'address1': '1455 W 29th St', 'address2': '',...
# 15   {'address1': '4401 Bridge Ave', 'address2': ''...
# 16   {'address1': '4960 Pearl Rd', 'address2': '', ...
# 17   {'address1': '2038 E 4th St', 'address2': '', ...
# 18   {'address1': '2572 Scranton Rd', 'address2': '...
# 19   {'address1': '2537 Lorain Ave', 'address2': ''...
# 20   {'address1': '2549 Lorain Ave', 'address2': No...
# 21   {'address1': '806 Literary Rd', 'address2': ''...
# 22   {'address1': '2058 W 25th St', 'address2': '',...
# 23   {'address1': '2095 Columbus Rd', 'address2': N...
# 24   {'address1': '2043 E 4th St', 'address2': '', ...
# 25   {'address1': '2393 Professor Ave', 'address2':...
# 26   {'address1': '2523 Market Ave', 'address2': ''...
# 27   {'address1': '2247 Professor Ave', 'address2':...
# 28   {'address1': '700 W St Clair Ave', 'address2':...
# 29   {'address1': '530 Euclid Ave', 'address2': '',...
# ..                                                 ...
# 470  {'address1': '', 'address2': '', 'address3': '...
# 471  {'address1': '2102 Freeman Ave', 'address2': '...
# 472  {'address1': '4630 Warrensville Center Rd', 'a...
# 473  {'address1': '2207 Chester Ave', 'address2': N...
# 474  {'address1': '14651 Lorain Ave', 'address2': '...
# 475  {'address1': '1330 Old River Rd', 'address2': ...
# 476  {'address1': '538 Superior Ave', 'address2': '...
# 477  {'address1': None, 'address2': None, 'address3...
# 478  {'address1': '5589 Broadview Rd', 'address2': ...
# 479  {'address1': '1780 Coventry Rd', 'address2': '...
# 480  {'address1': '3800 Whitman Ave', 'address2': '...
# 481  {'address1': '7403 Denison Ave', 'address2': '...
# 482  {'address1': '3519 Clark Ave', 'address2': '',...
# 483  {'address1': '1 Public Sq', 'address2': '', 'a...
# 484  {'address1': '5555 Brecksville Rd', 'address2'...
# 485  {'address1': '2240 Lee Rd', 'address2': '', 'a...
# 486  {'address1': '2017 East 9th St', 'address2': '...
# 487  {'address1': '5626 Broadview Rd', 'address2': ...
# 488  {'address1': '4007 Saint Clair Ave', 'address2...
# 489  {'address1': '10825 East Blvd', 'address2': ''...
# 490  {'address1': '1214 W 6th St', 'address2': '', ...
# 491  {'address1': '401 Euclid Ave', 'address2': Non...
# 492  {'address1': '11526 Clifton Dr', 'address2': '...
# 493  {'address1': '3323 W 25th St', 'address2': Non...
# 494  {'address1': '6901 Rockside Rd', 'address2': '...
# 495  {'address1': '3400 St Clair Ave', 'address2': ...
# 496  {'address1': '14809 Detroit Ave', 'address2': ...
# 497  {'address1': '2230 Euclid Ave', 'address2': ''...
# 498  {'address1': '5494 Pearl Rd', 'address2': '', ...
# 499  {'address1': '3537 W 105th St', 'address2': ''...
#
#                                    name         phone price  rating  \
# 0                                  Lola  +12166215652   $$$     4.0
# 1                              Townhall  +12163449400    $$     4.0
# 2                            L'Albatros  +12167917880   $$$     4.5
# 3                   Slyman's Restaurant  +12166213760    $$     4.5
# 4           Sokolowski's University Inn  +12167719236    $$     4.5
# 5           Great Lakes Brewing Company  +12167714404    $$     4.0
# 6                               Momocho  +12166942122    $$     4.0
# 7                          Lucky's Cafe  +12166227773    $$     4.0
# 8                             Happy Dog  +12166519474     $     4.0
# 9                          Superior Pho  +12167817462     $     4.0
# 10                 Mia Bella Restaurant  +12167952355    $$     4.5
# 11               Soho Chicken + Whiskey  +12162989090    $$     4.5
# 12                          Mabel's BBQ  +12164178823    $$     4.0
# 13           Porco Lounge and Tiki Room  +12168029222    $$     4.5
# 14          Rising Star Coffee Roasters  +12162733573     $     4.5
# 15                     Mason's Creamery  +12167621095     $     4.5
# 16                    Jack Frost Donuts  +12163513638     $     4.5
# 17                The Greenhouse Tavern  +12164430511   $$$     3.5
# 18                     Tremont Taphouse  +12162984451    $$     4.0
# 19                    Crop Bistro & Bar  +12166962767   $$$     4.0
# 20                            Boaz Cafe  +12164589225     $     4.5
# 21                               Barrio  +12169997714    $$     4.0
# 22                          Bakersfield  +12164430460    $$     4.5
# 23                    Velvet Tango Room  +12162418869   $$$     4.0
# 24               Butcher and the Brewer  +12163310805    $$     4.0
# 25       The Bourbon Street Barrel Room  +12162984400    $$     4.0
# 26                           Flying Fig  +12162414243    $$     4.0
# 27                                Ginko  +12162741202   $$$     4.5
# 28                    Blue Point Grille  +12168757827   $$$     4.0
# 29                       Pour Cleveland  +12164790395    $$     4.0
# ..                                  ...           ...   ...     ...
# 470                  Touch Supper Truck  +12166315200     $     4.5
# 471                    Duck Island Club  +12166217676     $     4.0
# 472     Cleveland Tiffin- Punjabi Dhaba  +12162207002    $$     4.5
# 473                     Joe Maxx Coffee  +12164597408     $     4.5
# 474    Rubin's Family Restaurant & Deli  +12166715556     $     3.5
# 475           East End Restaurant & Bar  +12167859996    $$     3.5
# 476                       Guys Pizza Co  +12162985100     $     3.0
# 477               Wrap It Up Food Truck  +14402736345     $     4.5
# 478                     Casamel's Pizza  +12166619700     $     4.5
# 479                          Pho & Rice  +12165631122    $$     4.0
# 480         Cha Spirits & Pizza Kitchen  +12166319242    $$     5.0
# 481                           La Fiesta  +12162123423     $     4.5
# 482               Mazzone & Sons Bakery  +12166317280     $     4.0
# 483                       Public Square                 NaN     4.0
# 484                             Cozumel  +12164471070    $$     4.0
# 485           Zoma Ethiopian Restaurant  +12164653239    $$     4.5
# 486                Azure Rooftop Lounge  +12163316321    $$     3.0
# 487  Gentile's Bakery - Catering & Deli  +12163511161     $     4.5
# 488                              Shay's  +12164316339     $     4.0
# 489            Cleveland History Center  +12167215722   NaN     4.0
# 490                            Dive Bar  +12166217827     $     3.5
# 491                        Rose's Braai  +12164155275     $     4.5
# 492                    Tick Tock Tavern  +12166316111     $     3.0
# 493     Cedarland Mediterranean Cuisine  +12167414414    $$     4.5
# 494                     Slyman's Tavern  +12166420062    $$     3.5
# 495                   Angie's Soul Cafe  +12164268890     $     3.5
# 496                       Souper Market  +12167127292     $     4.0
# 497                        Cafe Ah-Roma  +12167718700     $     3.5
# 498                   The Hot Dog Diner  +14408863647     $     4.0
# 499                        Dragon Light  +12162510504     $     4.0
#
#      review_count        transactions  \
# 0             981                  []
# 1             993                  []
# 2             604                  []
# 3             417                  []
# 4             464                  []
# 5             851                  []
# 6             695                  []
# 7             771                  []
# 8             606                  []
# 9             580            [pickup]
# 10            480                  []
# 11            370                  []
# 12            728                  []
# 13            319                  []
# 14            220                  []
# 15            203                  []
# 16            283          [delivery]
# 17            993  [delivery, pickup]
# 18            419                  []
# 19            409                  []
# 20            153                  []
# 21            537                  []
# 22            305                  []
# 23            293                  []
# 24            509                  []
# 25            379                  []
# 26            407                  []
# 27            247                  []
# 28            304                  []
# 29            267  [delivery, pickup]
# ..            ...                 ...
# 470            14                  []
# 471            22                  []
# 472           111  [pickup, delivery]
# 473            12                  []
# 474            46  [pickup, delivery]
# 475            43                  []
# 476            95  [pickup, delivery]
# 477            14                  []
# 478            19                  []
# 479           143            [pickup]
# 480            10                  []
# 481            11                  []
# 482            17                  []
# 483            19                  []
# 484           146            [pickup]
# 485            84  [pickup, delivery]
# 486            54                  []
# 487            48                  []
# 488            28                  []
# 489            22                  []
# 490            36                  []
# 491            12            [pickup]
# 492            77          [delivery]
# 493            12                  []
# 494           227                  []
# 495            41  [pickup, delivery]
# 496           140          [delivery]
# 497            40                  []
# 498           102                  []
# 499            17                  []
#
#                                                    url
# 0    https://www.yelp.com/biz/lola-cleveland?adjust...
# 1    https://www.yelp.com/biz/townhall-cleveland-2?...
# 2    https://www.yelp.com/biz/l-albatros-cleveland?...
# 3    https://www.yelp.com/biz/slymans-restaurant-cl...
# 4    https://www.yelp.com/biz/sokolowskis-universit...
# 5    https://www.yelp.com/biz/great-lakes-brewing-c...
# 6    https://www.yelp.com/biz/momocho-cleveland-2?a...
# 7    https://www.yelp.com/biz/luckys-cafe-cleveland...
# 8    https://www.yelp.com/biz/happy-dog-cleveland?a...
# 9    https://www.yelp.com/biz/superior-pho-clevelan...
# 10   https://www.yelp.com/biz/mia-bella-restaurant-...
# 11   https://www.yelp.com/biz/soho-chicken-whiskey-...
# 12   https://www.yelp.com/biz/mabels-bbq-cleveland?...
# 13   https://www.yelp.com/biz/porco-lounge-and-tiki...
    lat = r["coordinates"]["latitude"]
    lng = r["coordinates"]["longitude"]
    titles = r["categories"][0]["title"]
    ZIP = r["location"]["zip_code"]
    if len(r['transactions']) == 0:
        Tran = "NO"
    else:
        Tran = "YES"
    
    if r["price"] == str("$"):
        price = 1
    elif r["price"] == str("$$"):
        price = 2
    
    else: price = 3
        
    
        
    #print(price)
    #print(lat,lng)
    lats.append(lat)
    lngs.append(lng)
    Bus_titles.append(titles)
    ZIPS.append(ZIP)
    Trans.append(Tran)
    Prices.append(price)    


    #print(Prices)



    
#print(lats)
#print(lngs)
#DF = df.insert(loc=6, column='A', value=Bus_titles)
#df

# %%
# an DF that only have the cleaned Cols.

clean_df = pd.DataFrame(data={'Categories': Bus_titles, 
                              'latitude': lats,
                              'longitude': lngs,
                              'zip_code': ZIPS,
                              'Delivery': Trans,
                              'Price':Prices})
clean_df.head()
# Out:
#                Categories   latitude  longitude zip_code Delivery  Price
# 0               Wine Bars  41.498830 -81.690350    44115       NO      3
# 1          American (New)  41.485492 -81.703914    44113       NO      2
# 2                  French  41.511744 -81.606395    44106       NO      3
# 3  American (Traditional)  41.512860 -81.671250    44114       NO      2
# 4                  Polish  41.484750 -81.690050    44113       NO      2

# %%
# adding the cleaned col to the original DF

conat_df = pd.concat([df,clean_df], axis=1 )

# %%
# Display the new DF with a spacific col for better

Buis_df = conat_df[['name','Categories','zip_code','latitude','longitude','Delivery','rating','review_count','Price','location']]
Buis_df.head()
# Out:
#                           name              Categories zip_code   latitude  \
# 0                         Lola               Wine Bars    44115  41.498830
# 1                     Townhall          American (New)    44113  41.485492
# 2                   L'Albatros                  French    44106  41.511744
# 3          Slyman's Restaurant  American (Traditional)    44114  41.512860
# 4  Sokolowski's University Inn                  Polish    44113  41.484750
#
#    longitude Delivery  rating  review_count  Price  \
# 0 -81.690350       NO     4.0           981      3
# 1 -81.703914       NO     4.0           993      2
# 2 -81.606395       NO     4.5           604      3
# 3 -81.671250       NO     4.5           417      2
# 4 -81.690050       NO     4.5           464      2
#
#                                             location
# 0  {'address1': '2058 E 4th St', 'address2': '', ...
# 1  {'address1': '1909 W 25th St', 'address2': '',...
# 2  {'address1': '11401 Bellflower Rd', 'address2'...
# 3  {'address1': '3106 Saint Clair Ave NE', 'addre...
# 4  {'address1': '1201 University Rd', 'address2':...

# %%
Buis_df.boxplot("rating", by="Price", figsize=(20, 10))
group1 = df[Buis_df["Price"] == 1]["rating"]
group2 = df[Buis_df["Price"] == 2]["rating"]
group3 = df[Buis_df["Price"] == 3]["rating"]
stats.f_oneway(group1, group2, group3)
# Out:
# F_onewayResult(statistic=7.0886878070736694, pvalue=0.00092153968373446431)

# %%
Deliv = Buis_df['Delivery'].value_counts()
#print(Deliv)

Deliv.plot.bar(label = "Delivery vs No Delivery ")
plt.legend()

# %%
# creat a DF from a Categories and Delivery

groupby_cate_deliv = Buis_df.groupby(['Categories','Delivery'],
                                     as_index=False).sum().sort_values("rating", ascending=False)

cate_deliv_df = pd.DataFrame(groupby_cate_deliv)
cate_deliv_df.head()
# Out:
#         Categories Delivery     latitude    longitude  rating  review_count  \
# 2   American (New)       NO  1452.185213 -2858.808442   134.5          6861
# 33    Coffee & Tea       NO  1244.741531 -2450.220668   129.5          3154
# 69         Italian       NO   829.871672 -1633.393446    80.0          2201
# 93           Pizza       NO   746.750064 -1469.892277    74.5          1852
# 11            Bars       NO   788.128645 -1552.269313    74.5          3091
#
#     Price
# 2      72
# 33     34
# 69     47
# 93     29
# 11     33

# %%
# Is there a relation bet rating and prices?
# Set data
x = cate_deliv_df['rating']
y = cate_deliv_df['Price']
slope, intercept,r, p, std_err = stats.linregress(x, y)
fit = slope * x + intercept
#print(fit)



fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='o')
ax.plot(x, fit, 'r--')
fig.suptitle("Price vs Rating", fontsize=16, fontweight="bold")
plt.show()

# %%
x_axis = cate_deliv_df["Delivery"]
y_axis = cate_deliv_df["Categories"]

# %%
cate_deliv_df.tail(10)
# Out:
#               Categories Delivery   latitude  longitude  rating  review_count  \
# 105              Seafood      YES  41.499080 -81.698350     3.5           227
# 124                 Thai      YES  41.485268 -81.703735     3.5           123
# 112              Spanish       NO  41.498230 -81.700140     3.5           192
# 36              Cupcakes       NO  41.475735 -81.690926     3.5            38
# 23               Burgers      YES  41.501050 -81.676991     3.5            73
# 67                 Irish      YES  41.498561 -81.690233     3.5           252
# 74               Karaoke       NO  41.487780 -81.724340     3.5            43
# 87       Modern European       NO  41.456300 -81.644770     3.5            38
# 15               Bowling       NO  41.499507 -81.689842     3.0           209
# 90   New Mexican Cuisine       NO  41.510834 -81.696198     3.0           220
#
#      Price
# 105      2
# 124      2
# 112      3
# 36       1
# 23       1
# 67       2
# 74       1
# 87       1
# 15       2
# 90       2

# %%
higest_Categ = cate_deliv_df.loc[cate_deliv_df["Delivery"] == "YES" , ["rating"]]

lowest_categ = cate_deliv_df.loc[cate_deliv_df["Delivery"] == "NO" , ["rating"]]

#plt.show()

# %%
xa = cate_deliv_df['rating']
y = cate_deliv_df['Price']
slope, intercept,r, p, std_err = stats.linregress(x, y)
fit = slope * x + intercept
#print(fit)



fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='o')
ax.plot(x, fit, 'r--')
fig.suptitle("Price vs Rating", fontsize=16, fontweight="bold")
plt.show()

# %%
lowest_categ = cate_deliv_df.loc[cate_deliv_df["Delivery"] == "NO"]
lowest_categ.count()
# Out:
# Categories      90
# Delivery        90
# latitude        90
# longitude       90
# rating          90
# review_count    90
# Price           90
# dtype: int64

# %%
#cate_deliv_df.plt.scatter(cate_deliv_df['Categories'], cate_deliv_df['Delivery'])
plt.scatter(cate_deliv_df['Price'],cate_deliv_df['rating'], 
s = cate_deliv_df['review_count'] ,marker="o", facecolors="blue", edgecolors="black")

# %%
gruopby_Deliv =cate_deliv_df.groupby('rating').agg({"Delivery": "count"})
gruopby_Deliv.sum()
# Out:
# Delivery    136
# dtype: int64
